# %% [markdown]
# ### Importing Libraries

# %%
import numpy as np
import pandas  as pd 
import matplotlib.pyplot as plt
import seaborn as sns
import warnings

# %% [markdown]
# ### Loading Data

# %%
data = pd.read_excel("../Data/data_chg_rapid_all.xlsx")
data.head()
# Out:
#    Chargingevent   CPID  Connector  StartDate StartTime    EndDate   EndTime  \
# 0        4262365  50692          2 2018-03-05  23:55:00 2018-03-06  00:01:00
# 1        4262362  50339          2 2018-03-05  23:39:00 2018-03-06  00:40:00
# 2        4262354  50339          2 2018-03-05  23:21:00 2018-03-05  23:26:00
# 3        4262349  50692          2 2018-03-05  22:49:00 2018-03-05  23:27:00
# 4        4262341  50911          2 2018-03-05  22:32:00 2018-03-05  22:59:00
#
#    StartDate_num  StartTime_num  EndDate_num  EndTime_num  duration  TotalkWh  \
# 0          43164      23.916667        43165     0.016667       6.0      4.76
# 1          43164      23.650000        43165     0.666667      61.0      8.31
# 2          43164      23.350000        43164    23.433333       5.0      1.43
# 3          43164      22.816667        43164    23.450000      38.0     14.48
# 4          43164      22.533333        43164    22.983333      27.0      7.44
#
#    Cost                                           Site  \
# 0   0.0                       Dundee Ice Arena, Dundee
# 1   0.0       Public Works Dept, Clepington Rd. Dundee
# 2   0.0       Public Works Dept, Clepington Rd. Dundee
# 3   0.0                       Dundee Ice Arena, Dundee
# 4   0.0  Queen Street Car Park, Broughty Ferry, Dundee
#
#                                                Group  \
# 0  APT Controls; CYC; ChargePlace Scotland; Dunde...
# 1  APT Controls; CYC; ChargePlace Scotland; Dunde...
# 2  APT Controls; CYC; ChargePlace Scotland; Dunde...
# 3  APT Controls; CYC; ChargePlace Scotland; Dunde...
# 4  APT Controls; CYC; ChargePlace Scotland; Dunde...
#
#                       Model Model1  weekday  charger_id
# 0  APT Triple Rapid Charger  rapid        1           4
# 1  APT Triple Rapid Charger  rapid        1           2
# 2  APT Triple Rapid Charger  rapid        1           2
# 3  APT Triple Rapid Charger  rapid        1           4
# 4  APT Triple Rapid Charger  rapid        1           5

# %% [markdown]
# ### Checking for null values

# %%
data.isna().sum()
# Out:
# Chargingevent    0
# CPID             0
# Connector        0
# StartDate        0
# StartTime        0
# EndDate          0
# EndTime          0
# StartDate_num    0
# StartTime_num    0
# EndDate_num      0
# EndTime_num      0
# duration         0
# TotalkWh         0
# Cost             4
# Site             0
# Group            0
# Model            0
# Model1           0
# weekday          0
# charger_id       0
# dtype: int64

# %% [markdown]
# Only `Cost` column has 'nan' values.

# %% [markdown]
# Dropping `Cost` column since it has either has `0` or `nan` values and is not so useful for us.

# %%
data['Model1'].unique()
# Out:
# array(['rapid'], dtype=object)

# %% [markdown]
# Dropping `Model1` column which only contains value `rapid`

# %%
data.drop(columns = ['Cost', 'Model1'], axis = 1, inplace = True)

# %% [markdown]
# ### Sorting the data

# %%
data = data.sort_values(by=['CPID','Connector', 'StartDate', 'StartTime', 'EndDate', 'EndTime'])
data.head()
# Out:
#       Chargingevent   CPID  Connector  StartDate StartTime    EndDate  \
# 1347        7120839  50338          1 2018-03-23  12:35:00 2018-03-23
# 1340        7121028  50338          1 2018-03-23  13:13:00 2018-03-23
# 5143        7221636  50338          1 2018-05-01  15:51:00 2018-05-01
# 63          4259962  50338          2 2018-03-05  07:28:00 2018-03-05
# 51          4260697  50338          2 2018-03-05  10:47:00 2018-03-05
#
#        EndTime  StartDate_num  StartTime_num  EndDate_num  EndTime_num  \
# 1347  13:03:00          43182      12.583333        43182    13.050000
# 1340  13:20:00          43182      13.216667        43182    13.333333
# 5143  16:18:00          43221      15.850000        43221    16.300000
# 63    07:54:00          43164       7.466667        43164     7.900000
# 51    11:19:00          43164      10.783333        43164    11.316667
#
#       duration  TotalkWh                                           Site  \
# 1347      28.0     2.951  Social Work Building, Jack Martin Way, Dundee
# 1340       7.0     0.765  Social Work Building, Jack Martin Way, Dundee
# 5143      27.0     8.053  Social Work Building, Jack Martin Way, Dundee
# 63        26.0     0.570  Social Work Building, Jack Martin Way, Dundee
# 51        32.0    10.010  Social Work Building, Jack Martin Way, Dundee
#
#                                                   Group  \
# 1347  APT Controls; CYC; ChargePlace Scotland; Dunde...
# 1340  APT Controls; CYC; ChargePlace Scotland; Dunde...
# 5143  APT Controls; CYC; ChargePlace Scotland; Dunde...
# 63    APT Controls; CYC; ChargePlace Scotland; Dunde...
# 51    APT Controls; CYC; ChargePlace Scotland; Dunde...
#
#                          Model  weekday  charger_id
# 1347  APT Triple Rapid Charger        5           1
# 1340  APT Triple Rapid Charger        5           1
# 5143  APT Triple Rapid Charger        2           1
# 63    APT Triple Rapid Charger        1           1
# 51    APT Triple Rapid Charger        1           1

# %% [markdown]
# ### Checking for Anomalies

# %% [markdown]
# > We are checking if there are any anamolies in the start date and end date
#
# > For instance, unexpected year or month, like `2018-01-19` and `2018-05-19`
#
# > So we change it to `2018-01-19` and `2018-01-19`

# %%
def Date_Anomaly(data):
    wrong_date = []
    wrong_index = []
    for i in range(len(data) - 1):
        if data.iloc[i , 1] == data.iloc[i + 1, 1]:
            # start_time = datetime.strptime(data.iloc[i, 3], "%H:%M:%S")
            # end_time = datetime.strptime(data.iloc[i , 5], "%H:%M:%S")
            start_time = str(data.iloc[i , 3])
            end_time = str(data.iloc[i , 5])

            s_y = int(start_time.split('-')[0])    # Start Year
            s_m = int(start_time.split('-')[1])    # Start Month 
            
            e_y = int(end_time.split('-')[0])   # End Year
            e_m = int(end_time.split('-')[1])    # End Month 
        

            if (s_y == e_y) & (s_m != e_m):
                wrong_index.append(data.iloc[i].name)
                wrong_date.append(data.iloc[i])
                
    return wrong_date, wrong_index

# %%
wrong_date, wrong_index = Date_Anomaly(data)
len(wrong_date), len(wrong_index)
# Out:
# (5, 5)

# %% [markdown]
# > The dates we have received are the dates which are at their end of the month (basically moving to next month)
# > So, we don't have to change them

# %% [markdown]
# ### Adding `Occupancy Status` column into the dataset

# %%
data.insert(loc = 3, column = 'Occupancy Status', value = 1)

# %%
d1 = data.copy()

# %%
d1.columns
# Out:
# Index(['Chargingevent', 'CPID', 'Connector', 'Occupancy Status', 'StartDate',
#        'StartTime', 'EndDate', 'EndTime', 'StartDate_num', 'StartTime_num',
#        'EndDate_num', 'EndTime_num', 'duration', 'TotalkWh', 'Site', 'Group',
#        'Model', 'weekday', 'charger_id'],
#       dtype='object')

# %%
for i in range(len(data) - 1):
    if data.iloc[i , 1] == data.iloc[i + 1, 1]:
        new_row = [
                        data.iloc[i , 0],   # Chargingevent
                        data.iloc[i,  1],   # CPID
                        data.iloc[i , 2],   # Connector
                        0,                  # Occupancy Status
                        data.iloc[i , 6],   # StartDate
                        data.iloc[i , 7],   # StartTime 
                        data.iloc[i+1,4],   # EndDate      
                        data.iloc[i+1,5],   # EndTime
                        data.iloc[i , 10],   # StartDate_num
                        data.iloc[i , 11],   # StartTime_num
                        data.iloc[i+1, 8],   # EndDate_num 
                        data.iloc[i+1, 9],   # EndTime_num
                        data.iloc[i , 12],   # duration
                        data.iloc[i , 13],   # TotalkWh
                        data.iloc[i , 14],   # Site
                        data.iloc[i , 15],   # Group 
                        data.iloc[i , 16],   # Model
                        data.iloc[i , 17],   # weekday
                        data.iloc[i , 18]    #charger_id
                ]   
        d1.loc[len(d1) + i] = new_row

# %%
d2 = d1.copy()

# %%
d2 = d2.sort_values(by = ['CPID', 'Connector', 'StartDate', 'StartTime', "EndDate"])
d2.head(10)
# Out:
#       Chargingevent   CPID  Connector  Occupancy Status  StartDate StartTime  \
# 1347        7120839  50338          1                 1 2018-03-23  12:35:00
# 8870        7120839  50338          1                 0 2018-03-23  13:03:00
# 1340        7121028  50338          1                 1 2018-03-23  13:13:00
# 8872        7121028  50338          1                 0 2018-03-23  13:20:00
# 5143        7221636  50338          1                 1 2018-05-01  15:51:00
# 8874        7221636  50338          1                 0 2018-05-01  16:18:00
# 63          4259962  50338          2                 1 2018-03-05  07:28:00
# 8876        4259962  50338          2                 0 2018-03-05  07:54:00
# 51          4260697  50338          2                 1 2018-03-05  10:47:00
# 8878        4260697  50338          2                 0 2018-03-05  11:19:00
#
#         EndDate   EndTime  StartDate_num  StartTime_num  EndDate_num  \
# 1347 2018-03-23  13:03:00          43182      12.583333        43182
# 8870 2018-03-23  13:13:00          43182      13.050000        43182
# 1340 2018-03-23  13:20:00          43182      13.216667        43182
# 8872 2018-05-01  15:51:00          43182      13.333333        43221
# 5143 2018-05-01  16:18:00          43221      15.850000        43221
# 8874 2018-03-05  07:28:00          43221      16.300000        43164
# 63   2018-03-05  07:54:00          43164       7.466667        43164
# 8876 2018-03-05  10:47:00          43164       7.900000        43164
# 51   2018-03-05  11:19:00          43164      10.783333        43164
# 8878 2018-03-05  11:23:00          43164      11.316667        43164
#
#       EndTime_num  duration  TotalkWh  \
# 1347    13.050000      28.0     2.951
# 8870    13.216667      28.0     2.951
# 1340    13.333333       7.0     0.765
# 8872    15.850000       7.0     0.765
# 5143    16.300000      27.0     8.053
# 8874     7.466667      27.0     8.053
# 63       7.900000      26.0     0.570
# 8876    10.783333      26.0     0.570
# 51      11.316667      32.0    10.010
# 8878    11.383333      32.0    10.010
#
#                                                Site  \
# 1347  Social Work Building, Jack Martin Way, Dundee
# 8870  Social Work Building, Jack Martin Way, Dundee
# 1340  Social Work Building, Jack Martin Way, Dundee
# 8872  Social Work Building, Jack Martin Way, Dundee
# 5143  Social Work Building, Jack Martin Way, Dundee
# 8874  Social Work Building, Jack Martin Way, Dundee
# 63    Social Work Building, Jack Martin Way, Dundee
# 8876  Social Work Building, Jack Martin Way, Dundee
# 51    Social Work Building, Jack Martin Way, Dundee
# 8878  Social Work Building, Jack Martin Way, Dundee
#
#                                                   Group  \
# 1347  APT Controls; CYC; ChargePlace Scotland; Dunde...
# 8870  APT Controls; CYC; ChargePlace Scotland; Dunde...
# 1340  APT Controls; CYC; ChargePlace Scotland; Dunde...
# 8872  APT Controls; CYC; ChargePlace Scotland; Dunde...
# 5143  APT Controls; CYC; ChargePlace Scotland; Dunde...
# 8874  APT Controls; CYC; ChargePlace Scotland; Dunde...
# 63    APT Controls; CYC; ChargePlace Scotland; Dunde...
# 8876  APT Controls; CYC; ChargePlace Scotland; Dunde...
# 51    APT Controls; CYC; ChargePlace Scotland; Dunde...
# 8878  APT Controls; CYC; ChargePlace Scotland; Dunde...
#
#                          Model  weekday  charger_id
# 1347  APT Triple Rapid Charger        5           1
# 8870  APT Triple Rapid Charger        5           1
# 1340  APT Triple Rapid Charger        5           1
# 8872  APT Triple Rapid Charger        5           1
# 5143  APT Triple Rapid Charger        2           1
# 8874  APT Triple Rapid Charger        2           1
# 63    APT Triple Rapid Charger        1           1
# 8876  APT Triple Rapid Charger        1           1
# 51    APT Triple Rapid Charger        1           1
# 8878  APT Triple Rapid Charger        1           1

# %%
d2.to_csv("../Data/Data.csv")
